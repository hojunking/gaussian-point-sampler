# %%
import numpy as np
import os

# 작업 디렉토리 설정
base_dir = "/home/knuvi/Desktop/song/Pointcept/data/vox004_opacity/train"  # 실제 경로
scene_dirs = [d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))]

print(f"Found {len(scene_dirs)} scene directories in {base_dir}")

# 각 scene에 대한 검증 함수
def validate_scene(scene_dir):
    scene_path = os.path.join(base_dir, scene_dir)
    print(f"\nProcessing {scene_dir}:")

    # 필수 파일 목록
    required_files = {
        'coord': 'coord.npy',
        'color': 'color.npy',
        'normal': 'normal.npy',
        'segment20': 'segment20.npy',
        'segment200': 'segment200.npy',
        'instance': 'instance.npy',
        'features': 'features.npy'
    }

    # 데이터 로드
    data = {}
    for key, file_name in required_files.items():
        file_path = os.path.join(scene_path, file_name)
        if not os.path.exists(file_path):
            print(f"Error: {file_name} not found in {scene_dir}")
            return
        data[key] = np.load(file_path)

    # 데이터 크기 확인
    n_points = data['coord'].shape[0]
    print(f"- Number of points: {n_points}")

    # 각 데이터의 차원 확인
    expected_shapes = {
        'coord': (n_points, 3),  # (N, 3)
        'color': (n_points, 3),  # (N, 3)
        'normal': (n_points, 3),  # (N, 3)
        'segment20': (n_points,),  # (N,)
        'segment200': (n_points,),  # (N,)
        'instance': (n_points,),  # (N,)
        'features': (n_points, 7)  # (N, 1) - opacity만 포함
    }

    for key, expected_shape in expected_shapes.items():
        actual_shape = data[key].shape
        if actual_shape != expected_shape:
            print(f"Warning: {key} shape mismatch! Expected {expected_shape}, got {actual_shape}")
        else:
            print(f"- {key} shape: {actual_shape} (correct)")

    # Features 검증: opacity 값 확인
    features = data['features']  # (N, 1)
    opacity = features[:, 0]  # (N,)
    
    # 0이 아닌 값 카운트
    opacity_valid_count = np.sum(~np.isclose(opacity, 0, atol=1e-5))
    print(f"- Opacity valid points (not near zero): {opacity_valid_count} ({opacity_valid_count / n_points:.4f})")

    # 다른 속성 값 검증
    for key in ['coord', 'color', 'normal']:
        valid_count = np.sum(~np.all(np.isclose(data[key], 0, atol=1e-5), axis=1))
        print(f"- {key} valid points (not near zero): {valid_count} ({valid_count / n_points:.4f})")

    for key in ['segment20', 'segment200', 'instance']:
        valid_count = np.sum(data[key] != -1)  # -1은 무효 값으로 가정
        print(f"- {key} valid points (not -1): {valid_count} ({valid_count / n_points:.4f})")

# 모든 scene에 대해 검증 실행
for scene_dir in scene_dirs:
    validate_scene(scene_dir)
# Out:
# Found 47 scene directories in /home/knuvi/Desktop/song/Pointcept/data/vox004_opacity/train
#
# Processing scene0092_04:
# - Number of points: 262688
# - coord shape: (262688, 3) (correct)
# - color shape: (262688, 3) (correct)
# - normal shape: (262688, 3) (correct)
# - segment20 shape: (262688,) (correct)
# - segment200 shape: (262688,) (correct)
# - instance shape: (262688,) (correct)
# - features shape: (262688, 1) (correct)
# - Opacity valid points (not near zero): 262688 (1.0000)
# - coord valid points (not near zero): 262688 (1.0000)
# - color valid points (not near zero): 262688 (1.0000)
# - normal valid points (not near zero): 262685 (1.0000)
# - segment20 valid points (not -1): 180589 (0.6875)
# - segment200 valid points (not -1): 247112 (0.9407)
# - instance valid points (not -1): 249840 (0.9511)
#
# Processing scene0261_00:
# - Number of points: 217798
# - coord shape: (217798, 3) (correct)
# - color shape: (217798, 3) (correct)
# - normal shape: (217798, 3) (correct)
# - segment20 shape: (217798,) (correct)
# - segment200 shape: (217798,) (correct)
# - instance shape: (217798,) (correct)
# - features shape: (217798, 1) (correct)
# - Opacity valid points (not near zero): 217798 (1.0000)
# - coord valid points (not near zero): 217798 (1.0000)
# - color valid points (not near zero): 217798 (1.0000)
# - normal valid points (not near zero): 217797 (1.0000)
# - segment20 valid points (not -1): 160836 (0.7385)
# - segment200 valid points (not -1): 176572 (0.8107)
# - instance valid points (not -1): 176572 (0.8107)
#
# Processing scene0020_00:
# - Number of points: 195592
# - coord shape: (195592, 3) (correct)
# - color shape: (195592, 3) (correct)
# - normal shape: (195592, 3) (correct)
# - segment20 shape: (195592,) (correct)
# - segment200 shape: (195592,) (correct)
# - instance shape: (195592,) (correct)
# - features shape: (195592, 1) (correct)
# - Opacity valid points (not near zero): 195592 (1.0000)
# - coord valid points (not near zero): 195592 (1.0000)
# - color valid points (not near zero): 195592 (1.0000)
# - normal valid points (not near zero): 195592 (1.0000)
# - segment20 valid points (not -1): 106128 (0.5426)
# - segment200 valid points (not -1): 177620 (0.9081)
# - instance valid points (not -1): 177620 (0.9081)
#
# Processing scene0104_00:
# - Number of points: 134701
# - coord shape: (134701, 3) (correct)
# - color shape: (134701, 3) (correct)
# - normal shape: (134701, 3) (correct)
# - segment20 shape: (134701,) (correct)
# - segment200 shape: (134701,) (correct)
# - instance shape: (134701,) (correct)
# - features shape: (134701, 1) (correct)
# - Opacity valid points (not near zero): 134701 (1.0000)
# - coord valid points (not near zero): 134701 (1.0000)
# - color valid points (not near zero): 134701 (1.0000)
# - normal valid points (not near zero): 134701 (1.0000)
# - segment20 valid points (not -1): 101722 (0.7552)
# - segment200 valid points (not -1): 124046 (0.9209)
# - instance valid points (not -1): 129474 (0.9612)
#
# Processing scene0225_00:
# - Number of points: 240919
# - coord shape: (240919, 3) (correct)
# - color shape: (240919, 3) (correct)
# - normal shape: (240919, 3) (correct)
# - segment20 shape: (240919,) (correct)
# - segment200 shape: (240919,) (correct)
# - instance shape: (240919,) (correct)
# - features shape: (240919, 1) (correct)
# - Opacity valid points (not near zero): 240919 (1.0000)
# - coord valid points (not near zero): 240919 (1.0000)
# - color valid points (not near zero): 240919 (1.0000)
# - normal valid points (not near zero): 240919 (1.0000)
# - segment20 valid points (not -1): 216311 (0.8979)
# - segment200 valid points (not -1): 225528 (0.9361)
# - instance valid points (not -1): 225528 (0.9361)
#
# Processing scene0274_01:
# - Number of points: 192505
# - coord shape: (192505, 3) (correct)
# - color shape: (192505, 3) (correct)
# - normal shape: (192505, 3) (correct)
# - segment20 shape: (192505,) (correct)
# - segment200 shape: (192505,) (correct)
# - instance shape: (192505,) (correct)
# - features shape: (192505, 1) (correct)
# - Opacity valid points (not near zero): 192505 (1.0000)
# - coord valid points (not near zero): 192505 (1.0000)
# - color valid points (not near zero): 192505 (1.0000)
# - normal valid points (not near zero): 192505 (1.0000)
# - segment20 valid points (not -1): 173310 (0.9003)
# - segment200 valid points (not -1): 176888 (0.9189)
# - instance valid points (not -1): 176888 (0.9189)
#
# Processing scene0219_00:
# - Number of points: 58533
# - coord shape: (58533, 3) (correct)
# - color shape: (58533, 3) (correct)
# - normal shape: (58533, 3) (correct)
# - segment20 shape: (58533,) (correct)
# - segment200 shape: (58533,) (correct)
# - instance shape: (58533,) (correct)
# - features shape: (58533, 1) (correct)
# - Opacity valid points (not near zero): 58527 (0.9999)
# - coord valid points (not near zero): 58533 (1.0000)
# - color valid points (not near zero): 58533 (1.0000)
# - normal valid points (not near zero): 58533 (1.0000)
# - segment20 valid points (not -1): 40780 (0.6967)
# - segment200 valid points (not -1): 55211 (0.9432)
# - instance valid points (not -1): 55211 (0.9432)
#
# Processing scene0181_02:
# - Number of points: 306836
# - coord shape: (306836, 3) (correct)
# - color shape: (306836, 3) (correct)
# - normal shape: (306836, 3) (correct)
# - segment20 shape: (306836,) (correct)
# - segment200 shape: (306836,) (correct)
# - instance shape: (306836,) (correct)
# - features shape: (306836, 1) (correct)
# - Opacity valid points (not near zero): 306836 (1.0000)
# - coord valid points (not near zero): 306836 (1.0000)
# - color valid points (not near zero): 306836 (1.0000)
# - normal valid points (not near zero): 306836 (1.0000)
# - segment20 valid points (not -1): 240120 (0.7826)
# - segment200 valid points (not -1): 261270 (0.8515)
# - instance valid points (not -1): 261270 (0.8515)
#
# Processing scene0121_01:
# - Number of points: 121951
# - coord shape: (121951, 3) (correct)
# - color shape: (121951, 3) (correct)
# - normal shape: (121951, 3) (correct)
# - segment20 shape: (121951,) (correct)
# - segment200 shape: (121951,) (correct)
# - instance shape: (121951,) (correct)
# - features shape: (121951, 1) (correct)
# - Opacity valid points (not near zero): 121951 (1.0000)
# - coord valid points (not near zero): 121951 (1.0000)
# - color valid points (not near zero): 121951 (1.0000)
# - normal valid points (not near zero): 121950 (1.0000)
# - segment20 valid points (not -1): 36417 (0.2986)
# - segment200 valid points (not -1): 88978 (0.7296)
# - instance valid points (not -1): 92636 (0.7596)
#
# Processing scene0062_02:
# - Number of points: 72919
# - coord shape: (72919, 3) (correct)
# - color shape: (72919, 3) (correct)
# - normal shape: (72919, 3) (correct)
# - segment20 shape: (72919,) (correct)
# - segment200 shape: (72919,) (correct)
# - instance shape: (72919,) (correct)
# - features shape: (72919, 1) (correct)
# - Opacity valid points (not near zero): 72919 (1.0000)
# - coord valid points (not near zero): 72919 (1.0000)
# - color valid points (not near zero): 72919 (1.0000)
# - normal valid points (not near zero): 72919 (1.0000)
# - segment20 valid points (not -1): 66075 (0.9061)
# - segment200 valid points (not -1): 72033 (0.9878)
# - instance valid points (not -1): 72033 (0.9878)
#
# Processing scene0093_01:
# - Number of points: 124583
# - coord shape: (124583, 3) (correct)
# - color shape: (124583, 3) (correct)
# - normal shape: (124583, 3) (correct)
# - segment20 shape: (124583,) (correct)
# - segment200 shape: (124583,) (correct)
# - instance shape: (124583,) (correct)
# - features shape: (124583, 1) (correct)
# - Opacity valid points (not near zero): 124575 (0.9999)
# - coord valid points (not near zero): 124583 (1.0000)
# - color valid points (not near zero): 124583 (1.0000)
# - normal valid points (not near zero): 124583 (1.0000)
# - segment20 valid points (not -1): 95468 (0.7663)
# - segment200 valid points (not -1): 105554 (0.8473)
# - instance valid points (not -1): 105554 (0.8473)
#
# Processing scene0270_00:
# - Number of points: 298711
# - coord shape: (298711, 3) (correct)
# - color shape: (298711, 3) (correct)
# - normal shape: (298711, 3) (correct)
# - segment20 shape: (298711,) (correct)
# - segment200 shape: (298711,) (correct)
# - instance shape: (298711,) (correct)
# - features shape: (298711, 1) (correct)
# - Opacity valid points (not near zero): 298711 (1.0000)
# - coord valid points (not near zero): 298711 (1.0000)
# - color valid points (not near zero): 298711 (1.0000)
# - normal valid points (not near zero): 298711 (1.0000)
# - segment20 valid points (not -1): 225843 (0.7561)
# - segment200 valid points (not -1): 248159 (0.8308)
# - instance valid points (not -1): 250987 (0.8402)
#
# Processing scene0067_01:
# - Number of points: 45782
# - coord shape: (45782, 3) (correct)
# - color shape: (45782, 3) (correct)
# - normal shape: (45782, 3) (correct)
# - segment20 shape: (45782,) (correct)
# - segment200 shape: (45782,) (correct)
# - instance shape: (45782,) (correct)
# - features shape: (45782, 1) (correct)
# - Opacity valid points (not near zero): 45781 (1.0000)
# - coord valid points (not near zero): 45782 (1.0000)
# - color valid points (not near zero): 45782 (1.0000)
# - normal valid points (not near zero): 45782 (1.0000)
# - segment20 valid points (not -1): 41153 (0.8989)
# - segment200 valid points (not -1): 44315 (0.9680)
# - instance valid points (not -1): 44315 (0.9680)
#
# Processing scene0141_01:
# - Number of points: 198647
# - coord shape: (198647, 3) (correct)
# - color shape: (198647, 3) (correct)
# - normal shape: (198647, 3) (correct)
# - segment20 shape: (198647,) (correct)
# - segment200 shape: (198647,) (correct)
# - instance shape: (198647,) (correct)
# - features shape: (198647, 1) (correct)
# - Opacity valid points (not near zero): 198641 (1.0000)
# - coord valid points (not near zero): 198647 (1.0000)
# - color valid points (not near zero): 198647 (1.0000)
# - normal valid points (not near zero): 198647 (1.0000)
# - segment20 valid points (not -1): 137112 (0.6902)
# - segment200 valid points (not -1): 179687 (0.9046)
# - instance valid points (not -1): 181388 (0.9131)
#
# Processing scene0232_01:
# - Number of points: 85876
# - coord shape: (85876, 3) (correct)
# - color shape: (85876, 3) (correct)
# - normal shape: (85876, 3) (correct)
# - segment20 shape: (85876,) (correct)
# - segment200 shape: (85876,) (correct)
# - instance shape: (85876,) (correct)
# - features shape: (85876, 1) (correct)
# - Opacity valid points (not near zero): 85876 (1.0000)
# - coord valid points (not near zero): 85876 (1.0000)
# - color valid points (not near zero): 85876 (1.0000)
# - normal valid points (not near zero): 85875 (1.0000)
# - segment20 valid points (not -1): 75189 (0.8756)
# - segment200 valid points (not -1): 84458 (0.9835)
# - instance valid points (not -1): 84458 (0.9835)
#
# Processing scene0105_01:
# - Number of points: 38964
# - coord shape: (38964, 3) (correct)
# - color shape: (38964, 3) (correct)
# - normal shape: (38964, 3) (correct)
# - segment20 shape: (38964,) (correct)
# - segment200 shape: (38964,) (correct)
# - instance shape: (38964,) (correct)
# - features shape: (38964, 1) (correct)
# - Opacity valid points (not near zero): 38957 (0.9998)
# - coord valid points (not near zero): 38964 (1.0000)
# - color valid points (not near zero): 38964 (1.0000)
# - normal valid points (not near zero): 38964 (1.0000)
# - segment20 valid points (not -1): 35589 (0.9134)
# - segment200 valid points (not -1): 37462 (0.9615)
# - instance valid points (not -1): 37462 (0.9615)
#
# Processing scene0223_01:
# - Number of points: 214694
# - coord shape: (214694, 3) (correct)
# - color shape: (214694, 3) (correct)
# - normal shape: (214694, 3) (correct)
# - segment20 shape: (214694,) (correct)
# - segment200 shape: (214694,) (correct)
# - instance shape: (214694,) (correct)
# - features shape: (214694, 1) (correct)
# - Opacity valid points (not near zero): 214687 (1.0000)
# - coord valid points (not near zero): 214694 (1.0000)
# - color valid points (not near zero): 214694 (1.0000)
# - normal valid points (not near zero): 214694 (1.0000)
# - segment20 valid points (not -1): 184715 (0.8604)
# - segment200 valid points (not -1): 211064 (0.9831)
# - instance valid points (not -1): 211064 (0.9831)
#
# Processing scene0083_00:
# - Number of points: 35992
# - coord shape: (35992, 3) (correct)
# - color shape: (35992, 3) (correct)
# - normal shape: (35992, 3) (correct)
# - segment20 shape: (35992,) (correct)
# - segment200 shape: (35992,) (correct)
# - instance shape: (35992,) (correct)
# - features shape: (35992, 1) (correct)
# - Opacity valid points (not near zero): 35992 (1.0000)
# - coord valid points (not near zero): 35992 (1.0000)
# - color valid points (not near zero): 35992 (1.0000)
# - normal valid points (not near zero): 35992 (1.0000)
# - segment20 valid points (not -1): 34274 (0.9523)
# - segment200 valid points (not -1): 35743 (0.9931)
# - instance valid points (not -1): 35743 (0.9931)
#
# Processing scene0194_00:
# - Number of points: 198853
# - coord shape: (198853, 3) (correct)
# - color shape: (198853, 3) (correct)
# - normal shape: (198853, 3) (correct)
# - segment20 shape: (198853,) (correct)
# - segment200 shape: (198853,) (correct)
# - instance shape: (198853,) (correct)
# - features shape: (198853, 1) (correct)
# - Opacity valid points (not near zero): 198853 (1.0000)
# - coord valid points (not near zero): 198853 (1.0000)
# - color valid points (not near zero): 198853 (1.0000)
# - normal valid points (not near zero): 198853 (1.0000)
# - segment20 valid points (not -1): 124186 (0.6245)
# - segment200 valid points (not -1): 148420 (0.7464)
# - instance valid points (not -1): 155515 (0.7821)
#
# Processing scene0248_00:
# - Number of points: 134226
# - coord shape: (134226, 3) (correct)
# - color shape: (134226, 3) (correct)
# - normal shape: (134226, 3) (correct)
# - segment20 shape: (134226,) (correct)
# - segment200 shape: (134226,) (correct)
# - instance shape: (134226,) (correct)
# - features shape: (134226, 1) (correct)
# - Opacity valid points (not near zero): 134175 (0.9996)
# - coord valid points (not near zero): 134226 (1.0000)
# - color valid points (not near zero): 134226 (1.0000)
# - normal valid points (not near zero): 134226 (1.0000)
# - segment20 valid points (not -1): 119651 (0.8914)
# - segment200 valid points (not -1): 127440 (0.9494)
# - instance valid points (not -1): 127440 (0.9494)
#
# Processing scene0223_02:
# - Number of points: 181080
# - coord shape: (181080, 3) (correct)
# - color shape: (181080, 3) (correct)
# - normal shape: (181080, 3) (correct)
# - segment20 shape: (181080,) (correct)
# - segment200 shape: (181080,) (correct)
# - instance shape: (181080,) (correct)
# - features shape: (181080, 1) (correct)
# - Opacity valid points (not near zero): 181077 (1.0000)
# - coord valid points (not near zero): 181080 (1.0000)
# - color valid points (not near zero): 181080 (1.0000)
# - normal valid points (not near zero): 181080 (1.0000)
# - segment20 valid points (not -1): 155630 (0.8595)
# - segment200 valid points (not -1): 167356 (0.9242)
# - instance valid points (not -1): 167356 (0.9242)
#
# Processing scene0204_01:
# - Number of points: 173159
# - coord shape: (173159, 3) (correct)
# - color shape: (173159, 3) (correct)
# - normal shape: (173159, 3) (correct)
# - segment20 shape: (173159,) (correct)
# - segment200 shape: (173159,) (correct)
# - instance shape: (173159,) (correct)
# - features shape: (173159, 1) (correct)
# - Opacity valid points (not near zero): 173158 (1.0000)
# - coord valid points (not near zero): 173159 (1.0000)
# - color valid points (not near zero): 173159 (1.0000)
# - normal valid points (not near zero): 173159 (1.0000)
# - segment20 valid points (not -1): 160964 (0.9296)
# - segment200 valid points (not -1): 170931 (0.9871)
# - instance valid points (not -1): 170931 (0.9871)
#
# Processing scene0090_00:
# - Number of points: 116070
# - coord shape: (116070, 3) (correct)
# - color shape: (116070, 3) (correct)
# - normal shape: (116070, 3) (correct)
# - segment20 shape: (116070,) (correct)
# - segment200 shape: (116070,) (correct)
# - instance shape: (116070,) (correct)
# - features shape: (116070, 1) (correct)
# - Opacity valid points (not near zero): 116070 (1.0000)
# - coord valid points (not near zero): 116070 (1.0000)
# - color valid points (not near zero): 116070 (1.0000)
# - normal valid points (not near zero): 116070 (1.0000)
# - segment20 valid points (not -1): 85834 (0.7395)
# - segment200 valid points (not -1): 101440 (0.8740)
# - instance valid points (not -1): 105935 (0.9127)
#
# Processing scene0252_00:
# - Number of points: 146043
# - coord shape: (146043, 3) (correct)
# - color shape: (146043, 3) (correct)
# - normal shape: (146043, 3) (correct)
# - segment20 shape: (146043,) (correct)
# - segment200 shape: (146043,) (correct)
# - instance shape: (146043,) (correct)
# - features shape: (146043, 1) (correct)
# - Opacity valid points (not near zero): 146041 (1.0000)
# - coord valid points (not near zero): 146043 (1.0000)
# - color valid points (not near zero): 146043 (1.0000)
# - normal valid points (not near zero): 146043 (1.0000)
# - segment20 valid points (not -1): 119268 (0.8167)
# - segment200 valid points (not -1): 138847 (0.9507)
# - instance valid points (not -1): 138847 (0.9507)
#
# Processing scene0129_00:
# - Number of points: 179937
# - coord shape: (179937, 3) (correct)
# - color shape: (179937, 3) (correct)
# - normal shape: (179937, 3) (correct)
# - segment20 shape: (179937,) (correct)
# - segment200 shape: (179937,) (correct)
# - instance shape: (179937,) (correct)
# - features shape: (179937, 1) (correct)
# - Opacity valid points (not near zero): 179937 (1.0000)
# - coord valid points (not near zero): 179937 (1.0000)
# - color valid points (not near zero): 179937 (1.0000)
# - normal valid points (not near zero): 179937 (1.0000)
# - segment20 valid points (not -1): 157218 (0.8737)
# - segment200 valid points (not -1): 157891 (0.8775)
# - instance valid points (not -1): 170454 (0.9473)
#
# Processing scene0024_00:
# - Number of points: 339627
# - coord shape: (339627, 3) (correct)
# - color shape: (339627, 3) (correct)
# - normal shape: (339627, 3) (correct)
# - segment20 shape: (339627,) (correct)
# - segment200 shape: (339627,) (correct)
# - instance shape: (339627,) (correct)
# - features shape: (339627, 1) (correct)
# - Opacity valid points (not near zero): 339623 (1.0000)
# - coord valid points (not near zero): 339627 (1.0000)
# - color valid points (not near zero): 339627 (1.0000)
# - normal valid points (not near zero): 339627 (1.0000)
# - segment20 valid points (not -1): 237070 (0.6980)
# - segment200 valid points (not -1): 291009 (0.8568)
# - instance valid points (not -1): 292980 (0.8627)
#
# Processing scene0075_00:
# - Number of points: 103297
# - coord shape: (103297, 3) (correct)
# - color shape: (103297, 3) (correct)
# - normal shape: (103297, 3) (correct)
# - segment20 shape: (103297,) (correct)
# - segment200 shape: (103297,) (correct)
# - instance shape: (103297,) (correct)
# - features shape: (103297, 1) (correct)
# - Opacity valid points (not near zero): 103297 (1.0000)
# - coord valid points (not near zero): 103297 (1.0000)
# - color valid points (not near zero): 103297 (1.0000)
# - normal valid points (not near zero): 103297 (1.0000)
# - segment20 valid points (not -1): 83875 (0.8120)
# - segment200 valid points (not -1): 98405 (0.9526)
# - instance valid points (not -1): 98456 (0.9531)
#
# Processing scene0195_02:
# - Number of points: 106239
# - coord shape: (106239, 3) (correct)
# - color shape: (106239, 3) (correct)
# - normal shape: (106239, 3) (correct)
# - segment20 shape: (106239,) (correct)
# - segment200 shape: (106239,) (correct)
# - instance shape: (106239,) (correct)
# - features shape: (106239, 1) (correct)
# - Opacity valid points (not near zero): 106239 (1.0000)
# - coord valid points (not near zero): 106239 (1.0000)
# - color valid points (not near zero): 106239 (1.0000)
# - normal valid points (not near zero): 106235 (1.0000)
# - segment20 valid points (not -1): 66732 (0.6281)
# - segment200 valid points (not -1): 90694 (0.8537)
# - instance valid points (not -1): 90694 (0.8537)
#
# Processing scene0114_00:
# - Number of points: 226352
# - coord shape: (226352, 3) (correct)
# - color shape: (226352, 3) (correct)
# - normal shape: (226352, 3) (correct)
# - segment20 shape: (226352,) (correct)
# - segment200 shape: (226352,) (correct)
# - instance shape: (226352,) (correct)
# - features shape: (226352, 1) (correct)
# - Opacity valid points (not near zero): 226351 (1.0000)
# - coord valid points (not near zero): 226352 (1.0000)
# - color valid points (not near zero): 226352 (1.0000)
# - normal valid points (not near zero): 226352 (1.0000)
# - segment20 valid points (not -1): 188155 (0.8312)
# - segment200 valid points (not -1): 204182 (0.9021)
# - instance valid points (not -1): 204182 (0.9021)
#
# Processing scene0155_01:
# - Number of points: 230922
# - coord shape: (230922, 3) (correct)
# - color shape: (230922, 3) (correct)
# - normal shape: (230922, 3) (correct)
# - segment20 shape: (230922,) (correct)
# - segment200 shape: (230922,) (correct)
# - instance shape: (230922,) (correct)
# - features shape: (230922, 1) (correct)
# - Opacity valid points (not near zero): 230922 (1.0000)
# - coord valid points (not near zero): 230922 (1.0000)
# - color valid points (not near zero): 230922 (1.0000)
# - normal valid points (not near zero): 230922 (1.0000)
# - segment20 valid points (not -1): 211618 (0.9164)
# - segment200 valid points (not -1): 226697 (0.9817)
# - instance valid points (not -1): 226697 (0.9817)
#
# Processing scene0191_02:
# - Number of points: 130087
# - coord shape: (130087, 3) (correct)
# - color shape: (130087, 3) (correct)
# - normal shape: (130087, 3) (correct)
# - segment20 shape: (130087,) (correct)
# - segment200 shape: (130087,) (correct)
# - instance shape: (130087,) (correct)
# - features shape: (130087, 1) (correct)
# - Opacity valid points (not near zero): 130087 (1.0000)
# - coord valid points (not near zero): 130087 (1.0000)
# - color valid points (not near zero): 130087 (1.0000)
# - normal valid points (not near zero): 130087 (1.0000)
# - segment20 valid points (not -1): 68206 (0.5243)
# - segment200 valid points (not -1): 122353 (0.9405)
# - instance valid points (not -1): 122353 (0.9405)
#
# Processing scene0094_00:
# - Number of points: 121390
# - coord shape: (121390, 3) (correct)
# - color shape: (121390, 3) (correct)
# - normal shape: (121390, 3) (correct)
# - segment20 shape: (121390,) (correct)
# - segment200 shape: (121390,) (correct)
# - instance shape: (121390,) (correct)
# - features shape: (121390, 1) (correct)
# - Opacity valid points (not near zero): 121376 (0.9999)
# - coord valid points (not near zero): 121390 (1.0000)
# - color valid points (not near zero): 121390 (1.0000)
# - normal valid points (not near zero): 121390 (1.0000)
# - segment20 valid points (not -1): 85863 (0.7073)
# - segment200 valid points (not -1): 101774 (0.8384)
# - instance valid points (not -1): 101774 (0.8384)
#
# Processing scene0160_01:
# - Number of points: 115297
# - coord shape: (115297, 3) (correct)
# - color shape: (115297, 3) (correct)
# - normal shape: (115297, 3) (correct)
# - segment20 shape: (115297,) (correct)
# - segment200 shape: (115297,) (correct)
# - instance shape: (115297,) (correct)
# - features shape: (115297, 1) (correct)
# - Opacity valid points (not near zero): 115297 (1.0000)
# - coord valid points (not near zero): 115297 (1.0000)
# - color valid points (not near zero): 115297 (1.0000)
# - normal valid points (not near zero): 115297 (1.0000)
# - segment20 valid points (not -1): 109088 (0.9461)
# - segment200 valid points (not -1): 113093 (0.9809)
# - instance valid points (not -1): 113093 (0.9809)
#
# Processing scene0211_03:
# - Number of points: 198273
# - coord shape: (198273, 3) (correct)
# - color shape: (198273, 3) (correct)
# - normal shape: (198273, 3) (correct)
# - segment20 shape: (198273,) (correct)
# - segment200 shape: (198273,) (correct)
# - instance shape: (198273,) (correct)
# - features shape: (198273, 1) (correct)
# - Opacity valid points (not near zero): 198273 (1.0000)
# - coord valid points (not near zero): 198273 (1.0000)
# - color valid points (not near zero): 198273 (1.0000)
# - normal valid points (not near zero): 198269 (1.0000)
# - segment20 valid points (not -1): 131860 (0.6650)
# - segment200 valid points (not -1): 168107 (0.8479)
# - instance valid points (not -1): 173823 (0.8767)
#
# Processing scene0031_01:
# - Number of points: 291928
# - coord shape: (291928, 3) (correct)
# - color shape: (291928, 3) (correct)
# - normal shape: (291928, 3) (correct)
# - segment20 shape: (291928,) (correct)
# - segment200 shape: (291928,) (correct)
# - instance shape: (291928,) (correct)
# - features shape: (291928, 1) (correct)
# - Opacity valid points (not near zero): 291925 (1.0000)
# - coord valid points (not near zero): 291928 (1.0000)
# - color valid points (not near zero): 291928 (1.0000)
# - normal valid points (not near zero): 291928 (1.0000)
# - segment20 valid points (not -1): 230974 (0.7912)
# - segment200 valid points (not -1): 276031 (0.9455)
# - instance valid points (not -1): 276031 (0.9455)
#
# Processing scene0273_00:
# - Number of points: 312352
# - coord shape: (312352, 3) (correct)
# - color shape: (312352, 3) (correct)
# - normal shape: (312352, 3) (correct)
# - segment20 shape: (312352,) (correct)
# - segment200 shape: (312352,) (correct)
# - instance shape: (312352,) (correct)
# - features shape: (312352, 1) (correct)
# - Opacity valid points (not near zero): 312349 (1.0000)
# - coord valid points (not near zero): 312352 (1.0000)
# - color valid points (not near zero): 312352 (1.0000)
# - normal valid points (not near zero): 312352 (1.0000)
# - segment20 valid points (not -1): 188853 (0.6046)
# - segment200 valid points (not -1): 248934 (0.7970)
# - instance valid points (not -1): 288104 (0.9224)
#
# Processing scene0170_02:
# - Number of points: 62227
# - coord shape: (62227, 3) (correct)
# - color shape: (62227, 3) (correct)
# - normal shape: (62227, 3) (correct)
# - segment20 shape: (62227,) (correct)
# - segment200 shape: (62227,) (correct)
# - instance shape: (62227,) (correct)
# - features shape: (62227, 1) (correct)
# - Opacity valid points (not near zero): 62227 (1.0000)
# - coord valid points (not near zero): 62227 (1.0000)
# - color valid points (not near zero): 62227 (1.0000)
# - normal valid points (not near zero): 62227 (1.0000)
# - segment20 valid points (not -1): 53877 (0.8658)
# - segment200 valid points (not -1): 58243 (0.9360)
# - instance valid points (not -1): 58243 (0.9360)
#
# Processing scene0118_01:
# - Number of points: 166397
# - coord shape: (166397, 3) (correct)
# - color shape: (166397, 3) (correct)
# - normal shape: (166397, 3) (correct)
# - segment20 shape: (166397,) (correct)
# - segment200 shape: (166397,) (correct)
# - instance shape: (166397,) (correct)
# - features shape: (166397, 1) (correct)
# - Opacity valid points (not near zero): 166397 (1.0000)
# - coord valid points (not near zero): 166397 (1.0000)
# - color valid points (not near zero): 166397 (1.0000)
# - normal valid points (not near zero): 166397 (1.0000)
# - segment20 valid points (not -1): 154003 (0.9255)
# - segment200 valid points (not -1): 155277 (0.9332)
# - instance valid points (not -1): 155952 (0.9372)
#
# Processing scene0010_00:
# - Number of points: 208196
# - coord shape: (208196, 3) (correct)
# - color shape: (208196, 3) (correct)
# - normal shape: (208196, 3) (correct)
# - segment20 shape: (208196,) (correct)
# - segment200 shape: (208196,) (correct)
# - instance shape: (208196,) (correct)
# - features shape: (208196, 1) (correct)
# - Opacity valid points (not near zero): 208196 (1.0000)
# - coord valid points (not near zero): 208196 (1.0000)
# - color valid points (not near zero): 208196 (1.0000)
# - normal valid points (not near zero): 208196 (1.0000)
# - segment20 valid points (not -1): 119743 (0.5751)
# - segment200 valid points (not -1): 189932 (0.9123)
# - instance valid points (not -1): 189932 (0.9123)
#
# Processing scene0204_02:
# - Number of points: 201066
# - coord shape: (201066, 3) (correct)
# - color shape: (201066, 3) (correct)
# - normal shape: (201066, 3) (correct)
# - segment20 shape: (201066,) (correct)
# - segment200 shape: (201066,) (correct)
# - instance shape: (201066,) (correct)
# - features shape: (201066, 1) (correct)
# - Opacity valid points (not near zero): 201063 (1.0000)
# - coord valid points (not near zero): 201066 (1.0000)
# - color valid points (not near zero): 201066 (1.0000)
# - normal valid points (not near zero): 201066 (1.0000)
# - segment20 valid points (not -1): 187251 (0.9313)
# - segment200 valid points (not -1): 198618 (0.9878)
# - instance valid points (not -1): 198618 (0.9878)
#
# Processing scene0093_02:
# - Number of points: 129647
# - coord shape: (129647, 3) (correct)
# - color shape: (129647, 3) (correct)
# - normal shape: (129647, 3) (correct)
# - segment20 shape: (129647,) (correct)
# - segment200 shape: (129647,) (correct)
# - instance shape: (129647,) (correct)
# - features shape: (129647, 1) (correct)
# - Opacity valid points (not near zero): 129642 (1.0000)
# - coord valid points (not near zero): 129647 (1.0000)
# - color valid points (not near zero): 129647 (1.0000)
# - normal valid points (not near zero): 129647 (1.0000)
# - segment20 valid points (not -1): 93906 (0.7243)
# - segment200 valid points (not -1): 104411 (0.8053)
# - instance valid points (not -1): 104411 (0.8053)
#
# Processing scene0220_01:
# - Number of points: 404243
# - coord shape: (404243, 3) (correct)
# - color shape: (404243, 3) (correct)
# - normal shape: (404243, 3) (correct)
# - segment20 shape: (404243,) (correct)
# - segment200 shape: (404243,) (correct)
# - instance shape: (404243,) (correct)
# - features shape: (404243, 1) (correct)
# - Opacity valid points (not near zero): 404242 (1.0000)
# - coord valid points (not near zero): 404243 (1.0000)
# - color valid points (not near zero): 404243 (1.0000)
# - normal valid points (not near zero): 404243 (1.0000)
# - segment20 valid points (not -1): 292528 (0.7236)
# - segment200 valid points (not -1): 356449 (0.8818)
# - instance valid points (not -1): 356449 (0.8818)
#
# Processing scene0237_00:
# - Number of points: 35279
# - coord shape: (35279, 3) (correct)
# - color shape: (35279, 3) (correct)
# - normal shape: (35279, 3) (correct)
# - segment20 shape: (35279,) (correct)
# - segment200 shape: (35279,) (correct)
# - instance shape: (35279,) (correct)
# - features shape: (35279, 1) (correct)
# - Opacity valid points (not near zero): 35277 (0.9999)
# - coord valid points (not near zero): 35279 (1.0000)
# - color valid points (not near zero): 35279 (1.0000)
# - normal valid points (not near zero): 35279 (1.0000)
# - segment20 valid points (not -1): 33046 (0.9367)
# - segment200 valid points (not -1): 33690 (0.9550)
# - instance valid points (not -1): 33690 (0.9550)
#
# Processing scene0161_01:
# - Number of points: 45481
# - coord shape: (45481, 3) (correct)
# - color shape: (45481, 3) (correct)
# - normal shape: (45481, 3) (correct)
# - segment20 shape: (45481,) (correct)
# - segment200 shape: (45481,) (correct)
# - instance shape: (45481,) (correct)
# - features shape: (45481, 1) (correct)
# - Opacity valid points (not near zero): 45447 (0.9993)
# - coord valid points (not near zero): 45481 (1.0000)
# - color valid points (not near zero): 45481 (1.0000)
# - normal valid points (not near zero): 45481 (1.0000)
# - segment20 valid points (not -1): 43378 (0.9538)
# - segment200 valid points (not -1): 43378 (0.9538)
# - instance valid points (not -1): 43378 (0.9538)
#
# Processing scene0057_00:
# - Number of points: 366873
# - coord shape: (366873, 3) (correct)
# - color shape: (366873, 3) (correct)
# - normal shape: (366873, 3) (correct)
# - segment20 shape: (366873,) (correct)
# - segment200 shape: (366873,) (correct)
# - instance shape: (366873,) (correct)
# - features shape: (366873, 1) (correct)
# - Opacity valid points (not near zero): 366871 (1.0000)
# - coord valid points (not near zero): 366873 (1.0000)
# - color valid points (not near zero): 366873 (1.0000)
# - normal valid points (not near zero): 366873 (1.0000)
# - segment20 valid points (not -1): 101848 (0.2776)
# - segment200 valid points (not -1): 257114 (0.7008)
# - instance valid points (not -1): 258390 (0.7043)
#
# Processing scene0174_00:
# - Number of points: 170666
# - coord shape: (170666, 3) (correct)
# - color shape: (170666, 3) (correct)
# - normal shape: (170666, 3) (correct)
# - segment20 shape: (170666,) (correct)
# - segment200 shape: (170666,) (correct)
# - instance shape: (170666,) (correct)
# - features shape: (170666, 1) (correct)
# - Opacity valid points (not near zero): 170666 (1.0000)
# - coord valid points (not near zero): 170666 (1.0000)
# - color valid points (not near zero): 170666 (1.0000)
# - normal valid points (not near zero): 170666 (1.0000)
# - segment20 valid points (not -1): 128994 (0.7558)
# - segment200 valid points (not -1): 138173 (0.8096)
# - instance valid points (not -1): 141813 (0.8309)
#
# Processing scene0058_01:
# - Number of points: 189810
# - coord shape: (189810, 3) (correct)
# - color shape: (189810, 3) (correct)
# - normal shape: (189810, 3) (correct)
# - segment20 shape: (189810,) (correct)
# - segment200 shape: (189810,) (correct)
# - instance shape: (189810,) (correct)
# - features shape: (189810, 1) (correct)
# - Opacity valid points (not near zero): 189786 (0.9999)
# - coord valid points (not near zero): 189810 (1.0000)
# - color valid points (not near zero): 189810 (1.0000)
# - normal valid points (not near zero): 189810 (1.0000)
# - segment20 valid points (not -1): 146736 (0.7731)
# - segment200 valid points (not -1): 166666 (0.8781)
# - instance valid points (not -1): 166666 (0.8781)

# %%
import numpy as np

def validate_pointcept_data(data, scene_name="unknown"):
    """
    Pointcept 데이터의 포맷과 값을 검증.
    
    Args:
        data (dict): Pointcept 또는 병합된 데이터 딕셔너리.
        scene_name (str): 장면 이름 (로그용).
    
    Returns:
        dict: 검증 결과 및 통계 정보.
    """
    print(f"\nValidating data for scene: {scene_name}")
    required_keys = ['coord', 'color', 'normal', 'segment20']
    optional_keys = ['segment200', 'instance']
    all_keys = required_keys + optional_keys

    # 검증 결과 저장
    validation_results = {
        'scene_name': scene_name,
        'point_count': 0,
        'format_errors': [],
        'stats': {}
    }

    # 1. 키 존재 여부 확인
    for key in required_keys:
        if key not in data:
            validation_results['format_errors'].append(f"Required key '{key}' not found")
    for key in data:
        if key not in all_keys:
            validation_results['format_errors'].append(f"Unknown key '{key}' found")

    # 2. 데이터 타입 및 차원 확인
    num_points = len(data['coord'])
    validation_results['point_count'] = num_points
    checks = {
        'coord': {'dtype': np.float32, 'shape': (num_points, 3)},
        'color': {'dtype': np.uint8, 'shape': (num_points, 3)},
        'normal': {'dtype': np.float32, 'shape': (num_points, 3)},
        'segment20': {'dtype': np.int64, 'shape': (num_points,)},
        'segment200': {'dtype': np.int64, 'shape': (num_points,)},
        'instance': {'dtype': np.int64, 'shape': (num_points,)}
    }

    for key, check in checks.items():
        if key not in data:
            continue
        d = data[key]
        # 데이터 타입 확인
        if d.dtype != check['dtype']:
            validation_results['format_errors'].append(
                f"'{key}' has incorrect dtype. Expected {check['dtype']}, got {d.dtype}")
        # 차원 확인
        if d.shape != check['shape']:
            validation_results['format_errors'].append(
                f"'{key}' has incorrect shape. Expected {check['shape']}, got {d.shape}")

    # 3. 값 범위 확인 및 통계 계산
    # coord: 유한한 값인지 확인
    if not np.all(np.isfinite(data['coord'])):
        validation_results['format_errors'].append("'coord' contains non-finite values (inf or nan)")
    validation_results['stats']['coord_mean'] = np.mean(data['coord'], axis=0).tolist()
    validation_results['stats']['coord_std'] = np.std(data['coord'], axis=0).tolist()

    # color: 0~255 사이
    if np.any(data['color'] < 0) or np.any(data['color'] > 255):
        validation_results['format_errors'].append(
            f"'color' values must be between 0 and 255. Min: {data['color'].min()}, Max: {data['color'].max()}")
    validation_results['stats']['color_mean'] = np.mean(data['color'], axis=0).tolist()
    validation_results['stats']['color_std'] = np.std(data['color'], axis=0).tolist()

    # normal: 노름이 1에 가까운지 확인
    norms = np.linalg.norm(data['normal'], axis=1)
    norm_deviation = np.abs(norms - 1.0)
    if np.any(norm_deviation > 0.1):
        validation_results['format_errors'].append(
            f"'normal' vectors should be unit vectors. Max deviation: {norm_deviation.max():.4f}")
    validation_results['stats']['normal_norm_mean'] = float(np.mean(norms))
    validation_results['stats']['normal_norm_std'] = float(np.std(norms))

    # segment20: 0~19 사이 (또는 -1)
    segment20 = data['segment20']
    invalid_mask = (segment20 < -1) | ((segment20 >= 20) & (segment20 != -1))
    if np.any(invalid_mask):
        validation_results['format_errors'].append(
            f"'segment20' contains invalid values. Expected -1 or 0~19, got min={segment20.min()}, max={segment20.max()}")
    ignore_ratio = np.mean(segment20 == -1)
    validation_results['stats']['segment20_ignore_ratio'] = float(ignore_ratio)

    # segment200: 0~199 사이 (또는 -1)
    if 'segment200' in data:
        segment200 = data['segment200']
        invalid_mask = (segment200 < -1) | ((segment200 >= 200) & (segment200 != -1))
        if np.any(invalid_mask):
            validation_results['format_errors'].append(
                f"'segment200' contains invalid values. Expected -1 or 0~199, got min={segment200.min()}, max={segment200.max()}")
        ignore_ratio = np.mean(segment200 == -1)
        validation_results['stats']['segment200_ignore_ratio'] = float(ignore_ratio)

    # instance: -1 또는 0 이상
    if 'instance' in data:
        instance = data['instance']
        if np.any(instance < -1):
            validation_results['format_errors'].append(
                f"'instance' contains invalid values. Expected -1 or >=0, got min={instance.min()}")
        ignore_ratio = np.mean(instance == -1)
        validation_results['stats']['instance_ignore_ratio'] = float(ignore_ratio)

    # 결과 출력
    if validation_results['format_errors']:
        print("Validation failed with the following errors:")
        for error in validation_results['format_errors']:
            print(f"  - {error}")
    else:
        print("Validation passed successfully.")
    print(f"Point count: {validation_results['point_count']}")
    print("Statistics:")
    for key, value in validation_results['stats'].items():
        print(f"  {key}: {value}")

    return validation_results

# 사용 예시
# Pointcept 데이터 검증
pointcept_dir = "/home/knuvi/Desktop/song/Pointcept/data/scannet/train/scene0010_00"
pointcept_data = load_pointcept_data(pointcept_dir)
pointcept_results = validate_pointcept_data(pointcept_data, "pointcept_scene0010_00")

# 3DGS 병합 데이터 검증
merged_dir = "/home/knuvi/Desktop/song/Pointcept/data/pdistance00005_scale05_keep-dup/train/scene0010_00"  # 병합된 데이터 경로 (사용자가 지정해야 함)
three_dgs_merged_data = load_pointcept_data(merged_dir)
merged_results = validate_pointcept_data(three_dgs_merged_data, "3dgs_merged_scene0010_00")

# 결과 비교
print("\nComparison of Pointcept vs 3DGS Merged Data:")
print(f"Point count: Pointcept={pointcept_results['point_count']}, 3DGS Merged={merged_results['point_count']}")
print("Format Errors:")
print(f"  Pointcept: {len(pointcept_results['format_errors'])} errors")
for error in pointcept_results['format_errors']:
    print(f"    - {error}")
print(f"  3DGS Merged: {len(merged_results['format_errors'])} errors")
for error in merged_results['format_errors']:
    print(f"    - {error}")
print("Statistics Comparison:")
for key in pointcept_results['stats']:
    pointcept_val = pointcept_results['stats'][key]
    merged_val = merged_results['stats'].get(key, "N/A")
    print(f"  {key}: Pointcept={pointcept_val}, 3DGS Merged={merged_val}")
# Out:
# Warning: Negative values found in segment20: [-1 -1 -1 ... -1 -1 -1]
# Keeping negative values as ignore_index (-1) following Pointcept's approach
# Warning: Negative values found in segment200: [-1 -1 -1 ... -1 -1 -1]
# Keeping negative values as ignore_index (-1) following Pointcept's approach
# Warning: Negative values found in instance: [-1 -1 -1 ... -1 -1 -1]
# Keeping negative values as ignore_index (-1) following Pointcept's approach
# Loaded Pointcept data from /home/knuvi/Desktop/song/Pointcept/data/scannet/train/scene0010_00: 162573 points
# Segment20 label distribution: min=-1, max=19
#
# Validating data for scene: pointcept_scene0010_00
# Validation passed successfully.
# Point count: 162573
# Statistics:
#   coord_mean: [3.0450615882873535, 2.604457378387451, 0.7587577700614929]
#   coord_std: [1.445813536643982, 1.5191539525985718, 0.5272013545036316]
#   color_mean: [104.65806745277506, 86.74749189594829, 65.9369944578743]
#   color_std: [80.04755646823514, 74.4538527526319, 67.06124811205638]
#   normal_norm_mean: 0.9999808073043823
#   normal_norm_std: 2.5010729586938396e-05
#   segment20_ignore_ratio: 0.4307418821083452
#   segment200_ignore_ratio: 0.09110983988731217
#   instance_ignore_ratio: 0.09110983988731217
# Warning: Negative values found in segment20: [-1 -1 -1 ... -1 -1 -1]
# Keeping negative values as ignore_index (-1) following Pointcept's approach
# Warning: Negative values found in segment200: [-1 -1 -1 ... -1 -1 -1]
# Keeping negative values as ignore_index (-1) following Pointcept's approach
# Warning: Negative values found in instance: [-1 -1 -1 ... -1 -1 -1]
# Keeping negative values as ignore_index (-1) following Pointcept's approach
# Loaded Pointcept data from /home/knuvi/Desktop/song/Pointcept/data/pdistance00005_scale05_keep-dup/train/scene0010_00: 284857 points
# Segment20 label distribution: min=-1, max=19
#
# Validating data for scene: 3dgs_merged_scene0010_00
# Validation passed successfully.
# Point count: 284857
# Statistics:
#   coord_mean: [3.224740505218506, 2.529155731201172, 0.8010773658752441]
#   coord_std: [1.4395959377288818, 1.3974655866622925, 0.4635910391807556]
#   color_mean: [111.37546909501961, 90.77231031710647, 67.65852339946008]
#   color_std: [75.464157093931, 69.11054215318755, 63.45909540409096]
#   normal_norm_mean: 0.9999890327453613
#   normal_norm_std: 2.1121832105563954e-05
#   segment20_ignore_ratio: 0.49628058991002505
#   segment200_ignore_ratio: 0.10007828489382392
#   instance_ignore_ratio: 0.10007828489382392
#
# Comparison of Pointcept vs 3DGS Merged Data:
# Point count: Pointcept=162573, 3DGS Merged=284857
# Format Errors:
#   Pointcept: 0 errors
#   3DGS Merged: 0 errors
# Statistics Comparison:
#   coord_mean: Pointcept=[3.0450615882873535, 2.604457378387451, 0.7587577700614929], 3DGS Merged=[3.224740505218506, 2.529155731201172, 0.8010773658752441]
#   coord_std: Pointcept=[1.445813536643982, 1.5191539525985718, 0.5272013545036316], 3DGS Merged=[1.4395959377288818, 1.3974655866622925, 0.4635910391807556]
#   color_mean: Pointcept=[104.65806745277506, 86.74749189594829, 65.9369944578743], 3DGS Merged=[111.37546909501961, 90.77231031710647, 67.65852339946008]
#   color_std: Pointcept=[80.04755646823514, 74.4538527526319, 67.06124811205638], 3DGS Merged=[75.464157093931, 69.11054215318755, 63.45909540409096]
#   normal_norm_mean: Pointcept=0.9999808073043823, 3DGS Merged=0.9999890327453613
#   normal_norm_std: Pointcept=2.5010729586938396e-05, 3DGS Merged=2.1121832105563954e-05
#   segment20_ignore_ratio: Pointcept=0.4307418821083452, 3DGS Merged=0.49628058991002505
#   segment200_ignore_ratio: Pointcept=0.09110983988731217, 3DGS Merged=0.10007828489382392
#   instance_ignore_ratio: Pointcept=0.09110983988731217, 3DGS Merged=0.10007828489382392

# %%
import numpy as np
from sklearn.neighbors import NearestNeighbors

def compute_local_consistency(data, k=10):
    """
    로컬 일관성 계산.
    
    Args:
        data (dict): 데이터 딕셔너리 (coord, color, normal, segment20 등 포함).
        k (int): KNN 이웃 수.
    
    Returns:
        dict: 로컬 일관성 메트릭.
    """
    coords = data['coord']
    nbrs = NearestNeighbors(n_neighbors=k, algorithm='auto').fit(coords)
    distances, indices = nbrs.kneighbors(coords)

    metrics = {
        'color_variance': [],
        'normal_cosine_similarity': [],
        'label_consistency': []
    }

    for i in range(len(coords)):
        nearest_indices = indices[i][1:]  # 자기 자신 제외
        nearest_colors = data['color'][nearest_indices]
        nearest_normals = data['normal'][nearest_indices]
        nearest_labels = data['segment20'][nearest_indices]

        # 색상 분산
        color_var = np.var(nearest_colors, axis=0).mean()
        metrics['color_variance'].append(color_var)

        # 법선 코사인 유사도
        normal = data['normal'][i]
        cos_sims = []
        for j in range(len(nearest_normals)):
            norm = np.linalg.norm(normal) * np.linalg.norm(nearest_normals[j])
            if norm > 0:
                cos_sim = np.dot(normal, nearest_normals[j]) / norm
                cos_sims.append(cos_sim)
        metrics['normal_cosine_similarity'].append(np.mean(cos_sims) if cos_sims else 0)

        # 라벨 일치도
        label = data['segment20'][i]
        if label >= 0:  # 유효 라벨만 고려
            consistency = np.mean(nearest_labels == label)
            metrics['label_consistency'].append(consistency)

    # 평균 메트릭 계산
    result = {
        'color_variance': np.mean(metrics['color_variance']),
        'normal_cosine_similarity': np.mean(metrics['normal_cosine_similarity']),
        'label_consistency': np.mean(metrics['label_consistency']) if metrics['label_consistency'] else 0
    }
    return result

def validate_pattern_consistency(pointcept_dir, merged_dir, pointcept_count, scene_name="scene0010_00", k=10):
    """
    Pointcept와 병합 데이터 간 패턴 일치도 검증 (전체 데이터 포함).
    
    Args:
        pointcept_dir (str): Pointcept 데이터 경로.
        merged_dir (str): 병합 데이터 경로.
        pointcept_count (int): 병합 데이터에서 Pointcept 포인트 수.
        scene_name (str): 장면 이름.
        k (int): KNN 이웃 수.
    """
    # 데이터 로드
    pointcept_data = load_pointcept_data(pointcept_dir)
    merged_data = load_pointcept_data(merged_dir)

    # 병합 데이터에서 Pointcept와 3DGS 포인트 분리
    merged_pointcept_data = {
        'coord': merged_data['coord'][:pointcept_count],
        'color': merged_data['color'][:pointcept_count],
        'normal': merged_data['normal'][:pointcept_count],
        'segment20': merged_data['segment20'][:pointcept_count]
    }
    merged_3dgs_data = {
        'coord': merged_data['coord'][pointcept_count:],
        'color': merged_data['color'][pointcept_count:],
        'normal': merged_data['normal'][pointcept_count:],
        'segment20': merged_data['segment20'][pointcept_count:]
    }

    # 로컬 일관성 계산
    pointcept_metrics = compute_local_consistency(pointcept_data, k=k)
    merged_all_metrics = compute_local_consistency(merged_data, k=k)
    merged_3dgs_metrics = compute_local_consistency(merged_3dgs_data, k=k)

    # 결과 비교
    print(f"\nPattern Consistency Validation for {scene_name} (All Data):")
    print("Color Variance (lower is better):")
    print(f"  Pointcept: {pointcept_metrics['color_variance']:.4f}")
    print(f"  Merged (All): {merged_all_metrics['color_variance']:.4f}")
    print(f"  Merged (3DGS part): {merged_3dgs_metrics['color_variance']:.4f}")
    print(f"  Difference (Merged All - Pointcept): {merged_all_metrics['color_variance'] - pointcept_metrics['color_variance']:.4f}")
    print(f"  Difference (Merged 3DGS - Pointcept): {merged_3dgs_metrics['color_variance'] - pointcept_metrics['color_variance']:.4f}")

    print("\nNormal Cosine Similarity (higher is better):")
    print(f"  Pointcept: {pointcept_metrics['normal_cosine_similarity']:.4f}")
    print(f"  Merged (All): {merged_all_metrics['normal_cosine_similarity']:.4f}")
    print(f"  Merged (3DGS part): {merged_3dgs_metrics['normal_cosine_similarity']:.4f}")
    print(f"  Difference (Merged All - Pointcept): {merged_all_metrics['normal_cosine_similarity'] - pointcept_metrics['normal_cosine_similarity']:.4f}")
    print(f"  Difference (Merged 3DGS - Pointcept): {merged_3dgs_metrics['normal_cosine_similarity'] - pointcept_metrics['normal_cosine_similarity']:.4f}")

    print("\nLabel Consistency (higher is better):")
    print(f"  Pointcept: {pointcept_metrics['label_consistency']:.4f}")
    print(f"  Merged (All): {merged_all_metrics['label_consistency']:.4f}")
    print(f"  Merged (3DGS part): {merged_3dgs_metrics['label_consistency']:.4f}")
    print(f"  Difference (Merged All - Pointcept): {merged_all_metrics['label_consistency'] - pointcept_metrics['label_consistency']:.4f}")
    print(f"  Difference (Merged 3DGS - Pointcept): {merged_3dgs_metrics['label_consistency'] - pointcept_metrics['label_consistency']:.4f}")

# 사용 예시
pointcept_dir = "/home/knuvi/Desktop/song/Pointcept/data/scannet/train/scene0010_00"
merged_dir = "/home/knuvi/Desktop/song/Pointcept/data/pdistance00005_scale05_modi-attr/train/scene0010_00"
pointcept_count = 162573  # 병합 로그에서 Pointcept 포인트 수 확인
validate_pattern_consistency(pointcept_dir, merged_dir, pointcept_count, "scene0010_00", k=10)
# Out:
# Warning: Negative values found in segment20: [-1 -1 -1 ... -1 -1 -1]
# Keeping negative values as ignore_index (-1) following Pointcept's approach
# Warning: Negative values found in segment200: [-1 -1 -1 ... -1 -1 -1]
# Keeping negative values as ignore_index (-1) following Pointcept's approach
# Warning: Negative values found in instance: [-1 -1 -1 ... -1 -1 -1]
# Keeping negative values as ignore_index (-1) following Pointcept's approach
# Loaded Pointcept data from /home/knuvi/Desktop/song/Pointcept/data/scannet/train/scene0010_00: 162573 points
# Segment20 label distribution: min=-1, max=19
# Warning: Negative values found in segment20: [-1 -1 -1 ... -1 -1 -1]
# Keeping negative values as ignore_index (-1) following Pointcept's approach
# Warning: Negative values found in segment200: [-1 -1 -1 ... -1 -1 -1]
# Keeping negative values as ignore_index (-1) following Pointcept's approach
# Warning: Negative values found in instance: [-1 -1 -1 ... -1 -1 -1]
# Keeping negative values as ignore_index (-1) following Pointcept's approach
# Loaded Pointcept data from /home/knuvi/Desktop/song/Pointcept/data/pdistance00005_scale05_modi-attr/train/scene0010_00: 282959 points
# Segment20 label distribution: min=-1, max=19
#
# Pattern Consistency Validation for scene0010_00 (All Data):
# Color Variance (lower is better):
#   Pointcept: 370.8503
#   Merged (All): 307.2844
#   Merged (3DGS part): 400.5381
#   Difference (Merged All - Pointcept): -63.5659
#   Difference (Merged 3DGS - Pointcept): 29.6878
#
# Normal Cosine Similarity (higher is better):
#   Pointcept: 0.8132
#   Merged (All): 0.8868
#   Merged (3DGS part): 0.9607
#   Difference (Merged All - Pointcept): 0.0737
#   Difference (Merged 3DGS - Pointcept): 0.1476
#
# Label Consistency (higher is better):
#   Pointcept: 0.9554
#   Merged (All): 0.9662
#   Merged (3DGS part): 0.9754
#   Difference (Merged All - Pointcept): 0.0108
#   Difference (Merged 3DGS - Pointcept): 0.0200
