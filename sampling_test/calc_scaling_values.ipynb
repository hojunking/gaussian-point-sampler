# %%
import os
import numpy as np

import sys
sys.path.append('../')
from utils import load_3dgs_data
from fusion_utils import preprocess_3dgs_attributes

def compute_3dgs_min_max(path_3dgs_root, use_features=('scale', 'opacity', 'rotation')):
    """
    모든 Scene에서 3DGS 속성을 수집하여 각 속성의 최대/최소값 계산.
    
    Args:
        path_3dgs_root (str): 3DGS 데이터가 저장된 루트 경로.
        use_features (tuple): 사용할 3DGS 속성 ('scale', 'opacity', 'rotation' 중 선택).
    
    Returns:
        dict: 각 속성의 최대/최소값을 포함하는 딕셔너리.
    """
    # 모든 Scene 폴더 목록
    scene_folders = [f for f in os.listdir(path_3dgs_root) 
                     if os.path.isdir(os.path.join(path_3dgs_root, f))]
    
    # 속성별 리스트 초기화
    all_scales = []
    all_opacities = []
    all_rotations = []

    # 각 Scene의 속성 수집
    for scene_folder in scene_folders:
        path_3dgs = os.path.join(path_3dgs_root, scene_folder, "point_cloud.ply")
        print(f"Processing {scene_folder}...")
        
        # 1. 3DGS 데이터 로드
        _, _, vertex_data_3dgs = load_3dgs_data(path_3dgs)

        # 2. 3DGS 속성 전처리
        print(f"Preprocessing 3DGS attributes for {scene_folder}...")
        features_3dgs = preprocess_3dgs_attributes(vertex_data_3dgs)

        # 3. 속성 분리 (use_features에 따라 동적으로 처리)
        feature_idx = 0
        if 'scale' in use_features:
            scale = features_3dgs[:, feature_idx:feature_idx+3]  # [N, 3]
            all_scales.append(scale)
            feature_idx += 3
        if 'opacity' in use_features:
            opacity = features_3dgs[:, feature_idx:feature_idx+1]  # [N, 1]
            all_opacities.append(opacity)
            feature_idx += 1
        if 'rotation' in use_features:
            rotation = features_3dgs[:, feature_idx:feature_idx+3]  # [N, 3]
            all_rotations.append(rotation)

    # 속성 병합
    min_max_dict = {}
    if 'scale' in use_features:
        all_scales = np.concatenate(all_scales, axis=0)
        min_max_dict['scale_min'] = np.min(all_scales, axis=0)
        min_max_dict['scale_max'] = np.max(all_scales, axis=0)
    if 'opacity' in use_features:
        all_opacities = np.concatenate(all_opacities, axis=0)
        min_max_dict['opacity_min'] = np.min(all_opacities, axis=0)
        min_max_dict['opacity_max'] = np.max(all_opacities, axis=0)
    if 'rotation' in use_features:
        all_rotations = np.concatenate(all_rotations, axis=0)
        min_max_dict['rotation_min'] = np.min(all_rotations, axis=0)
        min_max_dict['rotation_max'] = np.max(all_rotations, axis=0)

    # 결과 출력
    print("\nComputed Min/Max Values:")
    for key, value in min_max_dict.items():
        print(f"{key}: {value}")

    return min_max_dict

path_3dgs_root = "/home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output"
# 최대/최소값 계산
min_max_dict = compute_3dgs_min_max(path_3dgs_root, use_features=('scale', 'opacity', 'rotation'))

# # 결과를 파일로 저장 (선택)
# import json
# with open(os.path.join(path_3dgs_root, "3dgs_min_max.json"), 'w') as f:
#     json.dump({k: v.tolist() for k, v in min_max_dict.items()}, f, indent=4)
# print(f"Min/Max values saved to {os.path.join(args.path_3dgs_root, '3dgs_min_max.json')}")
# Out:
# Processing scene0106_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0106_01/point_cloud.ply: 320586 points
# Preprocessing 3DGS attributes for scene0106_01...
# Processing scene0297_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0297_00/point_cloud.ply: 234785 points
# Preprocessing 3DGS attributes for scene0297_00...
# Processing scene0053_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0053_00/point_cloud.ply: 114834 points
# Preprocessing 3DGS attributes for scene0053_00...
# Processing scene0484_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0484_01/point_cloud.ply: 190612 points
# Preprocessing 3DGS attributes for scene0484_01...
# Processing scene0303_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0303_00/point_cloud.ply: 230198 points
# Preprocessing 3DGS attributes for scene0303_00...
# Processing scene0648_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0648_01/point_cloud.ply: 505865 points
# Preprocessing 3DGS attributes for scene0648_01...
# Processing scene0467_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0467_00/point_cloud.ply: 284766 points
# Preprocessing 3DGS attributes for scene0467_00...
# Processing scene0361_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0361_00/point_cloud.ply: 341808 points
# Preprocessing 3DGS attributes for scene0361_00...
# Processing scene0151_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0151_00/point_cloud.ply: 334917 points
# Preprocessing 3DGS attributes for scene0151_00...
# Processing scene0540_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0540_02/point_cloud.ply: 257286 points
# Preprocessing 3DGS attributes for scene0540_02...
# Processing scene0333_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0333_00/point_cloud.ply: 49607 points
# Preprocessing 3DGS attributes for scene0333_00...
# Processing scene0342_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0342_00/point_cloud.ply: 134502 points
# Preprocessing 3DGS attributes for scene0342_00...
# Processing scene0427_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0427_00/point_cloud.ply: 148582 points
# Preprocessing 3DGS attributes for scene0427_00...
# Processing scene0244_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0244_00/point_cloud.ply: 234292 points
# Preprocessing 3DGS attributes for scene0244_00...
# Processing scene0432_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0432_00/point_cloud.ply: 89099 points
# Preprocessing 3DGS attributes for scene0432_00...
# Processing scene0433_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0433_00/point_cloud.ply: 196697 points
# Preprocessing 3DGS attributes for scene0433_00...
# Processing scene0376_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0376_00/point_cloud.ply: 175682 points
# Preprocessing 3DGS attributes for scene0376_00...
# Processing scene0391_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0391_00/point_cloud.ply: 409036 points
# Preprocessing 3DGS attributes for scene0391_00...
# Processing scene0691_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0691_00/point_cloud.ply: 205184 points
# Preprocessing 3DGS attributes for scene0691_00...
# Processing scene0518_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0518_00/point_cloud.ply: 275267 points
# Preprocessing 3DGS attributes for scene0518_00...
# Processing scene0305_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0305_00/point_cloud.ply: 379930 points
# Preprocessing 3DGS attributes for scene0305_00...
# Processing scene0515_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0515_01/point_cloud.ply: 422537 points
# Preprocessing 3DGS attributes for scene0515_01...
# Processing scene0486_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0486_00/point_cloud.ply: 332310 points
# Preprocessing 3DGS attributes for scene0486_00...
# Processing scene0671_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0671_01/point_cloud.ply: 103143 points
# Preprocessing 3DGS attributes for scene0671_01...
# Processing scene0041_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0041_01/point_cloud.ply: 209559 points
# Preprocessing 3DGS attributes for scene0041_01...
# Processing scene0628_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0628_02/point_cloud.ply: 240310 points
# Preprocessing 3DGS attributes for scene0628_02...
# Processing scene0143_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0143_00/point_cloud.ply: 142903 points
# Preprocessing 3DGS attributes for scene0143_00...
# Processing scene0179_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0179_00/point_cloud.ply: 269023 points
# Preprocessing 3DGS attributes for scene0179_00...
# Processing scene0310_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0310_00/point_cloud.ply: 282629 points
# Preprocessing 3DGS attributes for scene0310_00...
# Processing scene0092_03...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0092_03/point_cloud.ply: 352016 points
# Preprocessing 3DGS attributes for scene0092_03...
# Processing scene0325_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0325_00/point_cloud.ply: 265029 points
# Preprocessing 3DGS attributes for scene0325_00...
# Processing scene0264_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0264_00/point_cloud.ply: 324885 points
# Preprocessing 3DGS attributes for scene0264_00...
# Processing scene0278_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0278_00/point_cloud.ply: 237268 points
# Preprocessing 3DGS attributes for scene0278_00...
# Processing scene0345_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0345_01/point_cloud.ply: 327809 points
# Preprocessing 3DGS attributes for scene0345_01...
# Processing scene0291_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0291_02/point_cloud.ply: 298701 points
# Preprocessing 3DGS attributes for scene0291_02...
# Processing scene0015_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0015_00/point_cloud.ply: 302187 points
# Preprocessing 3DGS attributes for scene0015_00...
# Processing scene0269_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0269_01/point_cloud.ply: 101199 points
# Preprocessing 3DGS attributes for scene0269_01...
# Processing scene0036_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0036_00/point_cloud.ply: 189383 points
# Preprocessing 3DGS attributes for scene0036_00...
# Processing scene0629_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0629_00/point_cloud.ply: 394319 points
# Preprocessing 3DGS attributes for scene0629_00...
# Processing scene0320_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0320_02/point_cloud.ply: 296949 points
# Preprocessing 3DGS attributes for scene0320_02...
# Processing scene0255_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0255_00/point_cloud.ply: 245325 points
# Preprocessing 3DGS attributes for scene0255_00...
# Processing scene0296_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0296_01/point_cloud.ply: 311987 points
# Preprocessing 3DGS attributes for scene0296_01...
# Processing scene0655_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0655_01/point_cloud.ply: 202774 points
# Preprocessing 3DGS attributes for scene0655_01...
# Processing scene0572_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0572_02/point_cloud.ply: 255615 points
# Preprocessing 3DGS attributes for scene0572_02...
# Processing scene0124_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0124_01/point_cloud.ply: 232337 points
# Preprocessing 3DGS attributes for scene0124_01...
# Processing scene0341_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0341_00/point_cloud.ply: 501850 points
# Preprocessing 3DGS attributes for scene0341_00...
# Processing scene0236_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0236_01/point_cloud.ply: 226720 points
# Preprocessing 3DGS attributes for scene0236_01...
# Processing scene0470_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0470_01/point_cloud.ply: 150491 points
# Preprocessing 3DGS attributes for scene0470_01...
# Processing scene0613_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0613_01/point_cloud.ply: 327777 points
# Preprocessing 3DGS attributes for scene0613_01...
# Processing scene0465_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0465_01/point_cloud.ply: 443466 points
# Preprocessing 3DGS attributes for scene0465_01...
# Processing scene0595_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0595_00/point_cloud.ply: 241246 points
# Preprocessing 3DGS attributes for scene0595_00...
# Processing scene0388_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0388_01/point_cloud.ply: 159321 points
# Preprocessing 3DGS attributes for scene0388_01...
# Processing scene0575_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0575_02/point_cloud.ply: 251576 points
# Preprocessing 3DGS attributes for scene0575_02...
# Processing scene0169_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0169_01/point_cloud.ply: 309389 points
# Preprocessing 3DGS attributes for scene0169_01...
# Processing scene0239_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0239_00/point_cloud.ply: 181115 points
# Preprocessing 3DGS attributes for scene0239_00...
# Processing scene0453_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0453_00/point_cloud.ply: 221402 points
# Preprocessing 3DGS attributes for scene0453_00...
# Processing scene0011_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0011_00/point_cloud.ply: 314733 points
# Preprocessing 3DGS attributes for scene0011_00...
# Processing scene0288_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0288_00/point_cloud.ply: 274470 points
# Preprocessing 3DGS attributes for scene0288_00...
# Processing scene0012_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0012_00/point_cloud.ply: 355042 points
# Preprocessing 3DGS attributes for scene0012_00...
# Processing scene0027_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0027_00/point_cloud.ply: 237757 points
# Preprocessing 3DGS attributes for scene0027_00...
# Processing scene0136_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0136_01/point_cloud.ply: 285378 points
# Preprocessing 3DGS attributes for scene0136_01...
# Processing scene0010_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0010_01/point_cloud.ply: 318641 points
# Preprocessing 3DGS attributes for scene0010_01...
# Processing scene0164_03...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0164_03/point_cloud.ply: 338933 points
# Preprocessing 3DGS attributes for scene0164_03...
# Processing scene0178_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0178_00/point_cloud.ply: 377262 points
# Preprocessing 3DGS attributes for scene0178_00...
# Processing scene0250_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0250_01/point_cloud.ply: 301466 points
# Preprocessing 3DGS attributes for scene0250_01...
# Processing scene0000_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0000_00/point_cloud.ply: 298627 points
# Preprocessing 3DGS attributes for scene0000_00...
# Processing scene0211_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0211_01/point_cloud.ply: 478644 points
# Preprocessing 3DGS attributes for scene0211_01...
# Processing scene0221_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0221_00/point_cloud.ply: 291061 points
# Preprocessing 3DGS attributes for scene0221_00...
# Processing scene0226_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0226_01/point_cloud.ply: 305466 points
# Preprocessing 3DGS attributes for scene0226_01...
# Processing scene0340_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0340_02/point_cloud.ply: 319083 points
# Preprocessing 3DGS attributes for scene0340_02...
# Processing scene0027_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0027_02/point_cloud.ply: 246362 points
# Preprocessing 3DGS attributes for scene0027_02...
# Processing scene0294_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0294_02/point_cloud.ply: 322834 points
# Preprocessing 3DGS attributes for scene0294_02...
# Processing scene0182_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0182_02/point_cloud.ply: 153656 points
# Preprocessing 3DGS attributes for scene0182_02...
# Processing scene0101_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0101_02/point_cloud.ply: 416465 points
# Preprocessing 3DGS attributes for scene0101_02...
# Processing scene0012_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0012_01/point_cloud.ply: 299054 points
# Preprocessing 3DGS attributes for scene0012_01...
# Processing scene0576_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0576_02/point_cloud.ply: 231651 points
# Preprocessing 3DGS attributes for scene0576_02...
# Processing scene0137_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0137_02/point_cloud.ply: 387642 points
# Preprocessing 3DGS attributes for scene0137_02...
# Processing scene0693_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0693_01/point_cloud.ply: 164679 points
# Preprocessing 3DGS attributes for scene0693_01...
# Processing scene0353_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0353_02/point_cloud.ply: 490746 points
# Preprocessing 3DGS attributes for scene0353_02...
# Processing scene0203_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0203_00/point_cloud.ply: 428549 points
# Preprocessing 3DGS attributes for scene0203_00...
# Processing scene0195_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0195_01/point_cloud.ply: 208355 points
# Preprocessing 3DGS attributes for scene0195_01...
# Processing scene0109_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0109_01/point_cloud.ply: 305979 points
# Preprocessing 3DGS attributes for scene0109_01...
# Processing scene0442_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0442_00/point_cloud.ply: 147880 points
# Preprocessing 3DGS attributes for scene0442_00...
# Processing scene0024_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0024_01/point_cloud.ply: 499441 points
# Preprocessing 3DGS attributes for scene0024_01...
# Processing scene0111_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0111_02/point_cloud.ply: 310941 points
# Preprocessing 3DGS attributes for scene0111_02...
# Processing scene0568_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0568_00/point_cloud.ply: 386652 points
# Preprocessing 3DGS attributes for scene0568_00...
# Processing scene0490_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0490_00/point_cloud.ply: 181865 points
# Preprocessing 3DGS attributes for scene0490_00...
# Processing scene0213_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0213_00/point_cloud.ply: 308036 points
# Preprocessing 3DGS attributes for scene0213_00...
# Processing scene0340_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0340_01/point_cloud.ply: 286693 points
# Preprocessing 3DGS attributes for scene0340_01...
# Processing scene0326_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0326_00/point_cloud.ply: 279918 points
# Preprocessing 3DGS attributes for scene0326_00...
# Processing scene0678_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0678_00/point_cloud.ply: 474243 points
# Preprocessing 3DGS attributes for scene0678_00...
# Processing scene0523_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0523_02/point_cloud.ply: 173707 points
# Preprocessing 3DGS attributes for scene0523_02...
# Processing scene0150_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0150_00/point_cloud.ply: 145227 points
# Preprocessing 3DGS attributes for scene0150_00...
# Processing scene0653_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0653_01/point_cloud.ply: 478782 points
# Preprocessing 3DGS attributes for scene0653_01...
# Processing scene0496_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0496_00/point_cloud.ply: 294795 points
# Preprocessing 3DGS attributes for scene0496_00...
# Processing scene0690_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0690_00/point_cloud.ply: 332549 points
# Preprocessing 3DGS attributes for scene0690_00...
# Processing scene0420_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0420_01/point_cloud.ply: 375231 points
# Preprocessing 3DGS attributes for scene0420_01...
# Processing scene0320_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0320_01/point_cloud.ply: 296057 points
# Preprocessing 3DGS attributes for scene0320_01...
# Processing scene0627_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0627_00/point_cloud.ply: 290682 points
# Preprocessing 3DGS attributes for scene0627_00...
# Processing scene0255_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0255_02/point_cloud.ply: 238168 points
# Preprocessing 3DGS attributes for scene0255_02...
# Processing scene0247_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0247_01/point_cloud.ply: 518452 points
# Preprocessing 3DGS attributes for scene0247_01...
# Processing scene0546_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0546_00/point_cloud.ply: 45402 points
# Preprocessing 3DGS attributes for scene0546_00...
# Processing scene0080_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0080_01/point_cloud.ply: 102983 points
# Preprocessing 3DGS attributes for scene0080_01...
# Processing scene0267_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0267_00/point_cloud.ply: 268865 points
# Preprocessing 3DGS attributes for scene0267_00...
# Processing scene0396_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0396_02/point_cloud.ply: 164387 points
# Preprocessing 3DGS attributes for scene0396_02...
# Processing scene0232_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0232_02/point_cloud.ply: 213192 points
# Preprocessing 3DGS attributes for scene0232_02...
# Processing scene0364_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0364_00/point_cloud.ply: 195123 points
# Preprocessing 3DGS attributes for scene0364_00...
# Processing scene0578_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0578_00/point_cloud.ply: 215817 points
# Preprocessing 3DGS attributes for scene0578_00...
# Processing scene0236_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0236_00/point_cloud.ply: 251140 points
# Preprocessing 3DGS attributes for scene0236_00...
# Processing scene0564_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0564_00/point_cloud.ply: 208746 points
# Preprocessing 3DGS attributes for scene0564_00...
# Processing scene0184_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0184_00/point_cloud.ply: 336428 points
# Preprocessing 3DGS attributes for scene0184_00...
# Processing scene0334_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0334_01/point_cloud.ply: 383405 points
# Preprocessing 3DGS attributes for scene0334_01...
# Processing scene0583_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0583_01/point_cloud.ply: 183143 points
# Preprocessing 3DGS attributes for scene0583_01...
# Processing scene0610_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0610_01/point_cloud.ply: 147647 points
# Preprocessing 3DGS attributes for scene0610_01...
# Processing scene0038_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0038_02/point_cloud.ply: 250227 points
# Preprocessing 3DGS attributes for scene0038_02...
# Processing scene0324_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0324_01/point_cloud.ply: 185029 points
# Preprocessing 3DGS attributes for scene0324_01...
# Processing scene0642_03...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0642_03/point_cloud.ply: 339029 points
# Preprocessing 3DGS attributes for scene0642_03...
# Processing scene0186_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0186_00/point_cloud.ply: 239183 points
# Preprocessing 3DGS attributes for scene0186_00...
# Processing scene0477_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0477_00/point_cloud.ply: 416058 points
# Preprocessing 3DGS attributes for scene0477_00...
# Processing scene0103_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0103_00/point_cloud.ply: 168156 points
# Preprocessing 3DGS attributes for scene0103_00...
# Processing scene0511_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0511_01/point_cloud.ply: 200981 points
# Preprocessing 3DGS attributes for scene0511_01...
# Processing scene0113_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0113_00/point_cloud.ply: 150083 points
# Preprocessing 3DGS attributes for scene0113_00...
# Processing scene0118_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0118_00/point_cloud.ply: 244591 points
# Preprocessing 3DGS attributes for scene0118_00...
# Processing scene0431_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0431_00/point_cloud.ply: 292187 points
# Preprocessing 3DGS attributes for scene0431_00...
# Processing scene0471_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0471_02/point_cloud.ply: 91669 points
# Preprocessing 3DGS attributes for scene0471_02...
# Processing scene0234_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0234_00/point_cloud.ply: 144033 points
# Preprocessing 3DGS attributes for scene0234_00...
# Processing scene0559_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0559_01/point_cloud.ply: 166098 points
# Preprocessing 3DGS attributes for scene0559_01...
# Processing scene0240_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0240_00/point_cloud.ply: 278417 points
# Preprocessing 3DGS attributes for scene0240_00...
# Processing scene0514_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0514_00/point_cloud.ply: 253479 points
# Preprocessing 3DGS attributes for scene0514_00...
# Processing scene0493_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0493_01/point_cloud.ply: 155852 points
# Preprocessing 3DGS attributes for scene0493_01...
# Processing scene0459_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0459_00/point_cloud.ply: 229030 points
# Preprocessing 3DGS attributes for scene0459_00...
# Processing scene0532_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0532_01/point_cloud.ply: 135064 points
# Preprocessing 3DGS attributes for scene0532_01...
# Processing scene0514_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0514_01/point_cloud.ply: 260579 points
# Preprocessing 3DGS attributes for scene0514_01...
# Processing scene0156_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0156_00/point_cloud.ply: 163637 points
# Preprocessing 3DGS attributes for scene0156_00...
# Processing scene0146_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0146_00/point_cloud.ply: 170547 points
# Preprocessing 3DGS attributes for scene0146_00...
# Processing scene0355_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0355_00/point_cloud.ply: 222247 points
# Preprocessing 3DGS attributes for scene0355_00...
# Processing scene0263_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0263_00/point_cloud.ply: 242169 points
# Preprocessing 3DGS attributes for scene0263_00...
# Processing scene0205_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0205_01/point_cloud.ply: 131468 points
# Preprocessing 3DGS attributes for scene0205_01...
# Processing scene0411_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0411_01/point_cloud.ply: 221774 points
# Preprocessing 3DGS attributes for scene0411_01...
# Processing scene0566_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0566_00/point_cloud.ply: 235576 points
# Preprocessing 3DGS attributes for scene0566_00...
# Processing scene0378_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0378_01/point_cloud.ply: 593523 points
# Preprocessing 3DGS attributes for scene0378_01...
# Processing scene0422_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0422_00/point_cloud.ply: 393598 points
# Preprocessing 3DGS attributes for scene0422_00...
# Processing scene0473_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0473_00/point_cloud.ply: 218844 points
# Preprocessing 3DGS attributes for scene0473_00...
# Processing scene0655_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0655_00/point_cloud.ply: 207265 points
# Preprocessing 3DGS attributes for scene0655_00...
# Processing scene0224_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0224_00/point_cloud.ply: 166463 points
# Preprocessing 3DGS attributes for scene0224_00...
# Processing scene0696_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0696_00/point_cloud.ply: 381025 points
# Preprocessing 3DGS attributes for scene0696_00...
# Processing scene0577_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0577_00/point_cloud.ply: 210176 points
# Preprocessing 3DGS attributes for scene0577_00...
# Processing scene0465_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0465_00/point_cloud.ply: 488730 points
# Preprocessing 3DGS attributes for scene0465_00...
# Processing scene0064_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0064_00/point_cloud.ply: 320539 points
# Preprocessing 3DGS attributes for scene0064_00...
# Processing scene0452_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0452_01/point_cloud.ply: 320495 points
# Preprocessing 3DGS attributes for scene0452_01...
# ...
# Preprocessing 3DGS attributes for scene0321_00...
# Processing scene0265_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0265_01/point_cloud.ply: 135086 points
# Preprocessing 3DGS attributes for scene0265_01...
# Processing scene0653_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0653_00/point_cloud.ply: 501110 points
# Preprocessing 3DGS attributes for scene0653_00...
# Processing scene0233_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0233_00/point_cloud.ply: 459662 points
# Preprocessing 3DGS attributes for scene0233_00...
# Processing scene0700_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0700_00/point_cloud.ply: 374493 points
# Preprocessing 3DGS attributes for scene0700_00...
# Processing scene0399_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0399_01/point_cloud.ply: 187495 points
# Preprocessing 3DGS attributes for scene0399_01...
# Processing scene0279_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0279_01/point_cloud.ply: 323898 points
# Preprocessing 3DGS attributes for scene0279_01...
# Processing scene0694_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0694_00/point_cloud.ply: 456844 points
# Preprocessing 3DGS attributes for scene0694_00...
# Processing scene0211_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0211_00/point_cloud.ply: 426845 points
# Preprocessing 3DGS attributes for scene0211_00...
# Processing scene0402_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0402_00/point_cloud.ply: 148820 points
# Preprocessing 3DGS attributes for scene0402_00...
# Processing scene0136_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0136_02/point_cloud.ply: 313132 points
# Preprocessing 3DGS attributes for scene0136_02...
# Processing scene0646_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0646_00/point_cloud.ply: 414601 points
# Preprocessing 3DGS attributes for scene0646_00...
# Processing scene0050_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0050_01/point_cloud.ply: 422103 points
# Preprocessing 3DGS attributes for scene0050_01...
# Processing scene0382_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0382_01/point_cloud.ply: 186384 points
# Preprocessing 3DGS attributes for scene0382_01...
# Processing scene0187_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0187_00/point_cloud.ply: 262096 points
# Preprocessing 3DGS attributes for scene0187_00...
# Processing scene0315_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0315_00/point_cloud.ply: 472913 points
# Preprocessing 3DGS attributes for scene0315_00...
# Processing scene0508_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0508_01/point_cloud.ply: 216881 points
# Preprocessing 3DGS attributes for scene0508_01...
# Processing scene0293_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0293_00/point_cloud.ply: 114509 points
# Preprocessing 3DGS attributes for scene0293_00...
# Processing scene0364_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0364_01/point_cloud.ply: 188705 points
# Preprocessing 3DGS attributes for scene0364_01...
# Processing scene0038_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0038_01/point_cloud.ply: 201522 points
# Preprocessing 3DGS attributes for scene0038_01...
# Processing scene0174_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0174_00/point_cloud.ply: 420067 points
# Preprocessing 3DGS attributes for scene0174_00...
# Processing scene0403_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0403_00/point_cloud.ply: 448123 points
# Preprocessing 3DGS attributes for scene0403_00...
# Processing scene0227_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0227_00/point_cloud.ply: 156876 points
# Preprocessing 3DGS attributes for scene0227_00...
# Processing scene0197_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0197_02/point_cloud.ply: 268555 points
# Preprocessing 3DGS attributes for scene0197_02...
# Processing scene0287_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0287_00/point_cloud.ply: 167265 points
# Preprocessing 3DGS attributes for scene0287_00...
# Processing scene0295_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0295_01/point_cloud.ply: 165511 points
# Preprocessing 3DGS attributes for scene0295_01...
# Processing scene0058_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0058_01/point_cloud.ply: 320850 points
# Preprocessing 3DGS attributes for scene0058_01...
# Processing scene0608_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0608_01/point_cloud.ply: 336560 points
# Preprocessing 3DGS attributes for scene0608_01...
# Processing scene0260_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0260_02/point_cloud.ply: 162357 points
# Preprocessing 3DGS attributes for scene0260_02...
# Processing scene0198_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0198_00/point_cloud.ply: 131376 points
# Preprocessing 3DGS attributes for scene0198_00...
# Processing scene0395_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0395_02/point_cloud.ply: 391631 points
# Preprocessing 3DGS attributes for scene0395_02...
# Processing scene0083_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0083_01/point_cloud.ply: 97671 points
# Preprocessing 3DGS attributes for scene0083_01...
# Processing scene0630_05...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0630_05/point_cloud.ply: 279396 points
# Preprocessing 3DGS attributes for scene0630_05...
# Processing scene0652_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0652_00/point_cloud.ply: 212140 points
# Preprocessing 3DGS attributes for scene0652_00...
# Processing scene0065_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0065_01/point_cloud.ply: 132196 points
# Preprocessing 3DGS attributes for scene0065_01...
# Processing scene0362_03...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0362_03/point_cloud.ply: 284851 points
# Preprocessing 3DGS attributes for scene0362_03...
# Processing scene0476_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0476_00/point_cloud.ply: 268519 points
# Preprocessing 3DGS attributes for scene0476_00...
# Processing scene0678_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0678_02/point_cloud.ply: 462386 points
# Preprocessing 3DGS attributes for scene0678_02...
# Processing scene0687_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0687_00/point_cloud.ply: 262135 points
# Preprocessing 3DGS attributes for scene0687_00...
# Processing scene0366_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0366_00/point_cloud.ply: 166879 points
# Preprocessing 3DGS attributes for scene0366_00...
# Processing scene0190_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0190_00/point_cloud.ply: 206332 points
# Preprocessing 3DGS attributes for scene0190_00...
# Processing scene0448_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0448_02/point_cloud.ply: 255252 points
# Preprocessing 3DGS attributes for scene0448_02...
# Processing scene0098_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0098_01/point_cloud.ply: 302334 points
# Preprocessing 3DGS attributes for scene0098_01...
# Processing scene0293_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0293_01/point_cloud.ply: 129975 points
# Preprocessing 3DGS attributes for scene0293_01...
# Processing scene0074_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0074_00/point_cloud.ply: 367954 points
# Preprocessing 3DGS attributes for scene0074_00...
# Processing scene0603_00...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0603_00/point_cloud.ply: 440051 points
# Preprocessing 3DGS attributes for scene0603_00...
# Processing scene0404_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0404_02/point_cloud.ply: 458200 points
# Preprocessing 3DGS attributes for scene0404_02...
# Processing scene0305_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0305_01/point_cloud.ply: 395326 points
# Preprocessing 3DGS attributes for scene0305_01...
# Processing scene0132_01...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0132_01/point_cloud.ply: 305710 points
# Preprocessing 3DGS attributes for scene0132_01...
# Processing scene0406_02...
# All 3DGS normals are zero. Estimating normals...
# After estimation - 3DGS normals norm: min=1.0000, max=1.0000, zero_count=0
# Loaded 3DGS data from /home/knuvi/Desktop/song/data/3dgs_scans/3dgs_output/scene0406_02/point_cloud.ply: 181259 points
# Preprocessing 3DGS attributes for scene0406_02...
#
# Computed Min/Max Values:
# scale_min: [0. 0. 0.]
# scale_max: [1. 1. 1.]
# opacity_min: [0.]
# opacity_max: [1.]
# rotation_min: [-0.99999714 -0.99999893 -0.99999986]
# rotation_max: [0.99999999 0.99999999 1.        ]

# %%
# 결과를 파일로 저장 (선택)
import json
with open(os.path.join('./', "3dgs_min_max.json"), 'w') as f:
    json.dump({k: v.tolist() for k, v in min_max_dict.items()}, f, indent=4)
print(f"Min/Max values saved to {os.path.join('./', '3dgs_min_max.json')}")
